# %% [markdown]
# # Data-analytiikan osaaja
#
# ## Koulutus: 13.2.2020-14.2.2020
#
# # Aihe: Datan lähteitä: avoin data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Terveyden ja hyvinvoinnin laitos (THL), avoin data:
# https://thl.fi/fi/tilastot-ja-data/aineistot-ja-palvelut/avoin-data

# %% [markdown]
# Työterveyslaitos, avoin data: https://www.ttl.fi/tutkimus-ja-kehittaminen/avoin-data/

# %% [markdown]
# Tilastokeskus, avoin data: http://www.stat.fi/org/avoindata/index.html

# %% [markdown]
# Esimerkkinä voit käyttää vaikka Fineli -tietopankkia: https://fineli.fi/fineli/fi/avoin-data
#
# Datan päälle on rakennettu nettisivusto, jossa voit tarkkailla ruokien ravintosisältöä: https://fineli.fi/fineli/fi/index

# %% [markdown]
# Harjoitus 1. Tutki millaisia data-aineistoja on saatavilla yllä olevista lähteistä.
#
# Millaisia dataformaatteja on käytössä?
#
# Miten voit ladata datan API-rajapinnan avulla?
#
# Lataa yksi kiinnostava data-aineisto ja "katsele" dataa, esim. visualisoimalla tai pääkomponenttianalyysin avulla.
